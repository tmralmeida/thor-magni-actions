# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
PATH = "thor-magni-actions/data/processed/thor_magni/"
SCENARIOS_ID = ["Scenario_2", "Scenario_3"]

# %%
scenarios_data  = {}
for scenario in SCENARIOS_ID:
    scenarios_data[scenario] = pd.read_csv(os.path.join(PATH, scenario + ".csv"), index_col="Time")

# %%
scenarios_data.keys()
# Out:
# dict_keys(['Scenario_2', 'Scenario_3'])

# %%
scenarios_data["Scenario_2"]
# Out:
#         frame_id         x         y         z      ag_id  \
# Time
# 0.01           1 -0.752555  2.998361  1.999823  Helmet_10
# 0.41          41 -0.751805  2.998101  2.000034  Helmet_10
# 0.81          81 -0.748640  2.994179  2.000421  Helmet_10
# 1.21         121 -0.742742  2.988799  2.000889  Helmet_10
# 1.61         161 -0.736776  2.984901  2.001065  Helmet_10
# ...          ...       ...       ...       ...        ...
# 235.61     23561 -6.132917  2.653496  1.887023   Helmet_5
# 236.01     23601 -6.545029  2.561548  1.832226   Helmet_5
# 236.41     23641 -6.680743  2.537312  1.811133   Helmet_5
# 236.81     23681 -6.578573  2.653624  1.839967   Helmet_5
# 237.21     23721 -6.414830  2.810383  1.863702   Helmet_5
#
#                   agent_type   x_delta   y_delta   x_speed   y_speed  ...  \
# Time                                                                  ...
# 0.01    Carrier-Large Object       NaN       NaN       NaN       NaN  ...
# ...

# %%
scenarios_data["Scenario_2"]["tracklet_id"].max()
# Out:
# 414

# %%
scenarios_data["Scenario_3"]["tracklet_id"] += scenarios_data["Scenario_2"]["tracklet_id"].max()

# %%
scenarios_data["Scenario_3"]
# Out:
#         frame_id         x         y         z      ag_id  \
# Time
# 1.61         161  7.669122  2.984181  2.007621  Helmet_10
# 2.01         201  7.641777  2.954470  2.000731  Helmet_10
# 2.41         241  7.447827  2.794055  1.999298  Helmet_10
# 2.81         281  7.158269  2.472996  1.982708  Helmet_10
# 3.21         321  6.878898  2.093349  1.975283  Helmet_10
# ...          ...       ...       ...       ...        ...
# 225.61     22561 -4.881211 -1.416687  1.892578   Helmet_5
# 226.01     22601 -5.318670 -1.177863  1.904079   Helmet_5
# 226.41     22641 -5.768345 -0.910268  1.886437   Helmet_5
# 226.81     22681 -6.218207 -0.694024  1.898264   Helmet_5
# 227.21     22721 -6.567109 -0.426717  1.905905   Helmet_5
#
#                   agent_type   x_delta   y_delta   x_speed   y_speed  ...  \
# Time                                                                  ...
# 1.61             Carrier-Box       NaN       NaN       NaN       NaN  ...
# ...

# %%
scenarios_data["Scenario_2"].shape, scenarios_data["Scenario_3"].shape
# Out:
# ((8260, 27), (16280, 27))

# %%
pd.concat([scenarios_data["Scenario_2"], scenarios_data["Scenario_3"]]).to_csv(os.path.join(PATH, "merged_data.csv"))
